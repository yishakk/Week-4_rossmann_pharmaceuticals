# %%
import os, sys
notebook_dir = os.getcwd()
sys.path.append(os.path.abspath(os.path.join(notebook_dir,'..')))

# %%
from scripts.eda_customer_behavior import CustomerBehaviorEDA
from scripts.data_load import load_data

# %%
# Initialize the object with file paths
eda = CustomerBehaviorEDA(
    train_path='../data/train.csv',
    test_path='../data/test.csv',
    store_path='../data/store.csv'
)

# %%
eda.run_analysis()
# Out:
# 2025-01-03 21:05:30,314 - INFO - Loading datasets...
# c:\Users\USER\Documents\10X Exercises\Week-4_rossmann_pharmaceuticals\scripts\eda_customer_behavior.py:25: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.train = pd.read_csv(self.train_path)
# 2025-01-03 21:05:30,953 - INFO - Cleaning data...
# 2025-01-03 21:05:31,094 - INFO - Columns with missing values: Index(['CompetitionDistance', 'CompetitionOpenSinceMonth',
#        'CompetitionOpenSinceYear', 'Promo2SinceWeek', 'Promo2SinceYear'],
#       dtype='object')
# 2025-01-03 21:05:31,471 - INFO - Detecting outliers...
# 2025-01-03 21:05:31,493 - INFO - Found 9731 outliers in Sales
# 2025-01-03 21:05:31,599 - INFO - Found 10501 outliers in Customers
# 2025-01-03 21:05:31,704 - INFO - Analyzing promo distributions...
# 2025-01-03 21:05:32,260 - INFO - Analyzing sales behavior around holidays...
# 2025-01-03 21:05:51,245 - INFO - Analyzing seasonal purchase behavior...
# 2025-01-03 21:05:51,337 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-01-03 21:05:51,341 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-01-03 21:05:51,409 - INFO - Analyzing correlation between sales and customers...
# 2025-01-03 21:05:51,431 - INFO - Correlation matrix:
#               Sales  Customers
# Sales      1.000000   0.909575
# Customers  0.909575   1.000000
# 2025-01-03 21:05:51,517 - INFO - Analyzing impact of promos on sales and customers...
# 2025-01-03 21:05:51,570 - INFO - Average sales with promo:
# Promo
# 0    4246.155097
# 1    7693.941189
# Name: Sales, dtype: float64
# 2025-01-03 21:05:51,572 - INFO - Average customers with promo:
# Promo
# 0    488.648294
# 1    774.771645
# Name: Customers, dtype: float64
# 2025-01-03 21:05:51,584 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-01-03 21:05:51,588 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-01-03 21:05:51,608 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-01-03 21:05:51,614 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-01-03 21:05:51,732 - INFO - Analyzing customer behavior during store opening and closing times...
# 2025-01-03 21:05:52,385 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-01-03 21:05:53,092 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-01-03 21:05:53,515 - INFO - Analyzing sales on weekdays vs weekends...
# 2025-01-03 21:05:53,781 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-01-03 21:05:53,786 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-01-03 21:05:53,862 - INFO - Analyzing impact of assortment types on sales...
# 2025-01-03 21:05:54,005 - INFO - Analyzing effect of competitor distance on sales...
# 2025-01-03 21:05:56,249 - INFO - Analyzing effect of new competitors...
# 2025-01-03 21:05:56,327 - INFO - Saving cleaned datasets...

# %%
# Check the cleaned training data
eda.train.head()

# Check the correlation between sales and customers
eda.train[['Sales', 'Customers']].corr()
